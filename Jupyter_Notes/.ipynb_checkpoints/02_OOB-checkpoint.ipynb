# %% [markdown]
# # Object Oriented Programming

# %% [markdown]
# Does it make sense? Nope. No idea. This is something to do with 'class' and inheritance

# %%
class Inventory:
    def __init__(self, name, items, is_new, cash=0):
        self.name=name
        self.items = items
        self.cash=cash
        self.is_new=is_new

    def new_user(self, bonus_cash_ammount=0):
        if self.is_new == True:
            bonus_cash_ammount = 500
            self.cash += 500
            print(f"Congrats for being a new User {self.name}! Here's your entry bonus: ",bonus_cash_ammount)
        elif self.is_new == False:
            print("Welcome back! ", self.name)
        else:
            print("Something went wrong! Please contact CS")
